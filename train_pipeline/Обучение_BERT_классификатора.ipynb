# %% [markdown]
# # Аугментация и загрузка датасета

# %%
import random

# Исходные данные
commands = [
    "отказ",
    "отмена",
    "подтверждение",
    "начать осаживание",
    "осадить на (количество) вагон",
    "продолжаем осаживание",
    "зарядка тормозной магистрали",
    "вышел из межвагонного пространства",
    "продолжаем роспуск",
    "растянуть автосцепки",
    "протянуть на (количество) вагон",
    "отцепка",
    "назад на башмак",
    "захожу в межвагонное,пространство",
    "остановка",
    "вперед на башмак",
    "сжать автосцепки",
    "назад с башмака",
    "тише",
    "вперед с башмака",
    "прекратить зарядку тормозной магистрали",
    "тормозить",
    "отпустить",
]


# Функция для создания аугментированных данных
def augment_data(num_examples=1000):
    augmented_data = []
    for _ in range(num_examples):
        command = random.choice(commands)

        # Изменение порядка слов
        words = command.split()
        random.shuffle(words)
        augmented_command = " ".join(words)

        # Замена слов синонимами
        synonyms = {
            "отказ": [
                "отвергание",
                "отрицание",
                "отклонение",
                "непринятие",
                "несогласие",
            ],
            "отмена": ["аннулирование", "упразднение", "отмена", "отзыв", "ликвидация"],
            "подтверждение": [
                "утверждение",
                "одобрение",
                "согласие",
                "признание",
                "верификация",
            ],
            "начать осаживание": [
                "начать торможение",
                "начать замедление",
                "начать отступление",
                "начать отход",
            ],
            "осадить на (количество) вагон": [
                "затормозить на (количество) вагон",
                "замедлить на (количество) вагон",
                "отступить на (количество) вагон",
            ],
            "продолжаем осаживание": [
                "продолжаем торможение",
                "продолжаем замедление",
                "продолжаем отступление",
                "продолжаем отход",
            ],
            "зарядка тормозной магистрали": [
                "наполнение тормозной системы",
                "подготовка тормозов",
                "активация тормозов",
            ],
            "вышел из межвагонного пространства": [
                "покинул пространство между вагонами",
                "отошел от пространства между вагонами",
                "удалился из пространства между вагонами",
            ],
            "продолжаем роспуск": [
                "продолжаем разъединение",
                "продолжаем расцепление",
                "продолжаем расформирование",
            ],
            "растянуть автосцепки": [
                "удлинить автосцепки",
                "вытянуть автосцепки",
                "расширить автосцепки",
            ],
            "протянуть на (количество) вагон": [
                "растянуть на (количество) вагон",
                "вытянуть на (количество) вагон",
                "удлинить на (количество) вагон",
            ],
            "отцепка": ["разъединение", "расцепление", "отсоединение"],
            "назад на башмак": [
                "отступить на башмак",
                "отойти на башмак",
                "вернуться на башмак",
            ],
            "захожу в межвагонное,пространство": [
                "вхожу в пространство между вагонами",
                "перемещаюсь в межвагонное пространство",
                "направляюсь в пространство между вагонами",
            ],
            "остановка": [
                "прекращение движения",
                "замедление до полной остановки",
                "завершение движения",
            ],
            "вперед на башмак": [
                "продвижение на башмак",
                "движение вперед на башмак",
                "приближение к башмаку",
            ],
            "сжать автосцепки": [
                "стянуть автосцепки",
                "сблизить автосцепки",
                "соединить автосцепки",
            ],
            "назад с башмака": [
                "отступить с башмака",
                "отойти с башмака",
                "вернуться с башмака",
            ],
            "тише": ["медленнее", "плавнее", "аккуратнее"],
            "вперед с башмака": [
                "продвижение с башмака",
                "движение вперед с башмака",
                "приближение с башмака",
            ],
            "прекратить зарядку тормозной магистрали": [
                "остановить наполнение тормозной системы",
                "завершить подготовку тормозов",
                "деактивировать тормоза",
            ],
            "тормозить": ["замедлять", "притормаживать", "снижать скорость"],
            "отпустить": ["освободить", "разжать", "ослабить"],
        }
        for word, syn_list in synonyms.items():
            if word in augmented_command:
                augmented_command = augmented_command.replace(
                    word, random.choice(syn_list)
                )

        # Добавление шума
        noise_words = [
            "автомобиль",
            "дерево",
            "погода",
            "музыка",
            "книга",
            "поезд",
            "рельсы",
            "платформа",
            "пассажир",
            "сигнал",
            "скорость",
            "маневр",
            "состав",
            "вагон",
            "колесо",
            "тормоз",
            "сцепка",
            "башмак",
            "расстояние",
            "время",
            "безопасность",
            "управление",
            "датчик",
            "сенсор",
            "электроника",
            "компьютер",
            "программа",
            "интерфейс",
            "экран",
            "кнопка",
            "рычаг",
            "педаль",
            "монитор",
            "сигнализация",
            "индикатор",
            "информация",
            "данные",
            "параметр",
            "режим",
            "настройка",
            "контроль",
            "диагностика",
            "ремонт",
            "обслуживание",
            "эксплуатация",
            "инструкция",
            "руководство",
            "оператор",
            "машинист",
            "диспетчер",
            "бригада",
            "система",
            "механизм",
            "устройство",
            "технология",
            "инновация",
            "развитие",
            "модернизация",
            "автоматизация",
            "цифровизация",
            "интеграция",
            "взаимодействие",
            "коммуникация",
            "координация",
            "оптимизация",
            "эффективность",
            "надежность",
            "безопасность",
            "качество",
            "производительность",
            "экономия",
            "энергия",
            "экология",
            "устойчивость",
        ]
        num_noise_words = random.randint(1, 5)
        noise_indices = random.sample(
            range(len(words)), min(len(words), num_noise_words)
        )
        for i in noise_indices:
            words.insert(i, random.choice(noise_words))
        augmented_command = " ".join(words)

        augmented_data.append(augmented_command)

    return augmented_data


# Создание 1000 примеров аугментированных данных
augmented_data = augment_data(num_examples=15)

# Вывод примеров
for example in augmented_data[:10]:
    print(example)
# Out:
# сигнализация остановка
# бригада отпустить
# машинист остановка
# прекратить сигнал состав магистрали зарядку тормозной
# пассажир расстояние башмака с информация вперед
# вышел экономия пространства из межвагонного
# колесо начать обслуживание осаживание
# рычаг с параметр производительность башмака вперед
# управление кнопка осаживание начать
# управление магистрали развитие прекратить контроль система зарядку тормозной

# %%
import pandas as pd

# Загрузка датасета, содержащего транскрибции аудио и метки классов
path = '/content/trans_text_all (1).csv'
data = pd.read_csv(path)[['Transcription', 'label']]
data.head(2)
# Out:
#                   Transcription  label
# 0                назад с башмак     17
# 1  зарядка тормозной магистраль     20

# %%
# Шумные (аугментированные) данные сопоставляются лэйблу шума
data_extra = pd.DataFrame({'label': [23 for _ in range(len(augmented_data))], 'Transcription': augmented_data})
# Объединение в один датасет с 24 метками классов
data = pd.concat([data, data_extra])
data
# Out:
#                                          Transcription  label
# 0                                       назад с башмак     17
# 1                         зарядка тормозной магистраль     20
# 2                          осадить на два восемь вагон      4
# 3                         зарядка тормозной магистраль      6
# 4                     выйти в межвагонный пространство      7
# ..                                                 ...    ...
# 995         диспетчер автосцепки руководство растянуть     23
# 996  качество зарядку магистрали тормозной эффектив...     23
# 997                                   рельсы остановка     23
# 998                 башмак растянуть дерево автосцепки     23
# 999                                диспетчер отпустить     23
#
# [7266 rows x 2 columns]

# %%
# Ещё один датасет с "неправильными" командами
data_extra = pd.read_csv('/content/generated.csv')
data_extra = data_extra.rename(columns={'transcriptions': 'Transcription'})
data_extra.head(2)
# Out:
#        Transcription  label
# 0   я вот так отмена     -1
# 1  тормозить хмм вот     -1

# %%
# Объединение в один общий
data_extra['label'] = data_extra['label'].apply(lambda x: 23)
data = pd.concat([data, data_extra])
data
# Out:
#                                          Transcription  label
# 0                                       назад с башмак     17
# 1                         зарядка тормозной магистраль     20
# 2                          осадить на два восемь вагон      4
# 3                         зарядка тормозной магистраль      6
# 4                     выйти в межвагонный пространство      7
# ..                                                 ...    ...
# 995        экология цифровизация осаживание продолжаем     23
# 996                                компьютер отпустить     23
# 997      автомобиль экология на вперед машинист башмак     23
# 998  интерфейс погода эффективность вагон оператор ...     23
# 999                            автоматизация отпустить     23
#
# [7266 rows x 2 columns]

# %% [markdown]
# # Обучение BERT

# %%
import torch
from transformers import AutoTokenizer, BertForSequenceClassification

# Загрузка моделей
device = 'cuda' if torch.cuda.is_available() else 'cpu'

tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")
model = BertForSequenceClassification.from_pretrained("cointegrated/rubert-tiny2", num_labels=len(data['label'].unique()))
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(83828, 312, padding_idx=0)
#       (position_embeddings): Embedding(2048, 312)
#       (token_type_embeddings): Embedding(2, 312)
# ...

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from sklearn.model_selection import train_test_split


# Формирование токенизированных датасетов
def preprocess_function(text):
    res = tokenizer(text["Transcription"], truncation=True, max_length=100)
    res["labels"] = text["label"]
    return res


train, test = train_test_split(data, test_size=0.1, stratify=data["label"])

train_dataset = train.apply(preprocess_function, axis=1)
test_dataset = test.apply(preprocess_function, axis=1)
train_dataset.reset_index(drop=True, inplace=True)
test_dataset.reset_index(drop=True, inplace=True)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score


# Метрики для валидации
def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    accuracy = accuracy_score(p.label_ids, preds)
    f1 = f1_score(p.label_ids, preds, average="macro")
    precision = precision_score(p.label_ids, preds, average="macro")
    recall = recall_score(p.label_ids, preds, average="macro")
    return {"accuracy": accuracy, "f1": f1, "precision": precision, "recall": recall}

# %%
from torch import nn
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="piter_clf",
    learning_rate=2e-5,
    per_device_train_batch_size=3,
    per_device_eval_batch_size=3,
    num_train_epochs=5,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='10900' max='10900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10900/10900 04:17, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.644300</td>
#       <td>0.556704</td>
#       <td>0.900963</td>
#       <td>0.750743</td>
#       <td>0.775814</td>
#       <td>0.747103</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.398800</td>
# ...

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='243' max='243' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [243/243 00:01]
#     </div>
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'eval_loss': 0.2844718098640442,
#  'eval_accuracy': 0.936726272352132,
#  'eval_f1': 0.8794689461092178,
#  'eval_precision': 0.8969199271585531,
#  'eval_recall': 0.8685671975574024,
#  'eval_runtime': 1.3272,
#  'eval_samples_per_second': 547.769,
#  'eval_steps_per_second': 183.092,
#  'epoch': 5.0}

# %%
# Сохранение модели
save_path = 'rubert_tiny_clf_extra'
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
# Out:
# ('rubert_tiny_clf_extra/tokenizer_config.json',
#  'rubert_tiny_clf_extra/special_tokens_map.json',
#  'rubert_tiny_clf_extra/vocab.txt',
#  'rubert_tiny_clf_extra/added_tokens.json',
#  'rubert_tiny_clf_extra/tokenizer.json')

# %% [markdown]
# # Тестирование

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.metrics import f1_score
from torch.utils.data import DataLoader, Dataset


class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_length,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }


# Подготовка данных (пример)
texts = test['Transcription'].tolist() # Ваши тексты
labels = test['label'].tolist()  # Ваши метки (например, 0 и 1 для бинарной классификации)

# Создание датасета и загрузчика данных
dataset = CustomDataset(texts, labels, tokenizer, max_length=128)
data_loader = DataLoader(dataset, batch_size=2)

# Переключение модели в режим оценки
model.eval()

# Список для хранения предсказаний и истинных меток
predictions = []
true_labels = []

with torch.no_grad():
    for batch in data_loader:
        input_ids = batch['input_ids'].to(model.device)
        attention_mask = batch['attention_mask'].to(model.device)
        labels = batch['labels'].to(model.device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        # Получаем предсказания (индексы классов)
        preds = torch.argmax(logits, dim=1)

        predictions.extend(preds.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())

# Вычисление F1 меры
f1 = f1_score(true_labels, predictions, average='weighted')
print(f'F1 Score: {f1}')
# Out:
# F1 Score: 0.9353593808398107

# %%
from sklearn.metrics import classification_report

print(classification_report(true_labels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        11
#            2       0.83      1.00      0.91        10
#            3       1.00      1.00      1.00        10
#            4       0.95      0.95      0.95       283
#            5       1.00      0.80      0.89        10
#            6       0.85      0.92      0.88        12
#            7       1.00      0.83      0.91        12
#            8       0.92      1.00      0.96        12
#            9       0.90      0.90      0.90        10
#           10       0.91      0.93      0.92       136
#           11       1.00      1.00      1.00         9
#           12       0.91      0.77      0.83        13
#           13       0.83      0.83      0.83        12
#           14       1.00      0.86      0.92         7
#           15       0.90      0.82      0.86        11
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(true_labels, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
import time

# Замер скорости работы на cpu и распознание шума

text_batch = ["бригада прием"]
model.to('cpu')

start = time.time()

tokenized_text = tokenizer(text_batch, return_tensors='pt')  # Нужно передавать список строк для батча или строку для одного примера
with torch.no_grad():
  outputs = model(**tokenized_text)
prediction = np.argmax(outputs.logits)

print((time.time() - start) * 1000)
print(prediction)
# Out:
# 7.568120956420898
# tensor(23)

# %%
# Замер размеров

num_params = sum(p.numel() for p in model.parameters())
model_size_mb = num_params * 4 / (1024 ** 2)

print(f"Количество параметров: {num_params}")
print(f"Размер модели: {model_size_mb:.2f} МБ")
# Out:
# Количество параметров: 29201280
# Размер модели: 111.39 МБ
